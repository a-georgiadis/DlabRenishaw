# %%
from pycromanager import Core, start_headless, stop_headless
mm_app_path = r'C:\Program Files\Micro-Manager-2.0'
config_file = r"C:\Program Files\Micro-Manager-2.0\MMConfig_Testing.cfg"

# %%
start_headless(mm_app_path, config_file, python_backend=True)

# %%
core = Core()

# %%
print(f"Connected to Micro-Manager Core: {core.get_version_info()}")
print(f"Camera Device: {core.get_camera_device()}")
# Out:
# Connected to Micro-Manager Core: MMCore version 11.10.0
# Camera Device: Demo FluorCam

# %%
stop_headless()
